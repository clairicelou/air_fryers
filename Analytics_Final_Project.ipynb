# %% [markdown]
# <a href="https://colab.research.google.com/github/clairicelou/air_fryers/blob/main/Analytics_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ds4e/air_fryers
# Out:
# Cloning into 'air_fryers'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 8.62 KiB | 8.62 MiB/s, done.

# %%
import pandas as pd
